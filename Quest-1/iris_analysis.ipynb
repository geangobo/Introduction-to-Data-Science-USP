# %% [markdown]
# ### Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %% [markdown]
# ### Iris db

# %%
df = pd.read_csv('../data/iris-with-errors.csv')

# %% [markdown]
# ### Leia os dados com erro (iris-with-errors.csv), faça a limpeza e remova as duas últimas colunas. Quantas linhas e colunas sobraram nos dados?

# %%
df.shape
# Out:
# (25, 5)

# %% [markdown]
# #### Note que temos valores NaN, "?" e duplicatas

# %%
df.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 2             ?           3           1.4         0.2     setosa
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 5           NaN         3.1           1.5         0.2     setosa
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 9           4.6         3.4           1.4         NaN     setosa
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# ...

# %% [markdown]
# #### Vamos precisar fazer um replace para lidar com os dados "?", transformando em NaN e depois dando drop NaN

# %%
df_clean = df.replace('?', np.nan)
df_clean.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 2           NaN           3           1.4         0.2     setosa
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 5           NaN         3.1           1.5         0.2     setosa
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 9           4.6         3.4           1.4         NaN     setosa
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# ...

# %%
df_clean = df_clean.dropna()
df_clean.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# 13          5.4         3.7           1.5         0.2     setosa
# 14          4.4         2.9           1.4         0.2  duplicada
# 15          4.8         3.4           1.6         0.2     setosa
# ...

# %%
df_clean = df_clean.drop_duplicates()
df_clean.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 3           4.7         3.2           1.3         0.2     setosa
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# 13          5.4         3.7           1.5         0.2     setosa
# 15          4.8         3.4           1.6         0.2     setosa
# 16          4.8           3           1.4         0.1     setosa
# 18          4.3           3           1.1         0.1     setosa
# 19          5.8           4           1.2         0.2     setosa
# 20          5.7         4.4           1.5         0.4     setosa
# ...

# %%
# Retirando as duas últimas colunas
df_clean = df_clean.iloc[:, :-2]

# %%
# Quantas linhas e colunas sobraram nos dados?
print(f'Linhas: {df_clean.shape[0]}, Colunas: {df_clean.shape[1]}')
# Out:
# Linhas: 14, Colunas: 3

# %% [markdown]
# ### Leia os dados com erro novamente e insira a media de cada atributo onde for encontrada NaN e '?'. Quais os valores das medianas obtidas para os atributos?

# %%
df = pd.read_csv('../data/iris-with-errors.csv')
df.tail(12)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 13          5.4         3.7           1.5         0.2     setosa
# 14          4.4         2.9           1.4         0.2  duplicada
# 15          4.8         3.4           1.6         0.2     setosa
# 16          4.8           3           1.4         0.1     setosa
# 17          4.4         2.9           1.4         0.2  duplicada
# 18          4.3           3           1.1         0.1     setosa
# 19          5.8           4           1.2         0.2     setosa
# 20          5.7         4.4           1.5         0.4     setosa
# 21          5.4         3.9           1.3           ?     setosa
# 22          5.1         3.5           1.4         0.3     setosa
# 23          5.7           ?           1.7         0.3     setosa
# 24          NaN         3.8           1.5         0.3     setosa

# %%
df_clean = df.replace("?", np.nan)
df_clean.tail(12)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 13          5.4         3.7           1.5         0.2     setosa
# 14          4.4         2.9           1.4         0.2  duplicada
# 15          4.8         3.4           1.6         0.2     setosa
# 16          4.8           3           1.4         0.1     setosa
# 17          4.4         2.9           1.4         0.2  duplicada
# 18          4.3           3           1.1         0.1     setosa
# 19          5.8           4           1.2         0.2     setosa
# 20          5.7         4.4           1.5         0.4     setosa
# 21          5.4         3.9           1.3         NaN     setosa
# 22          5.1         3.5           1.4         0.3     setosa
# 23          5.7         NaN           1.7         0.3     setosa
# 24          NaN         3.8           1.5         0.3     setosa

# %%
for col in df_clean.columns:
    df_clean[col] = pd.to_numeric(df_clean[col], errors='ignore')

df_clean = df_clean.apply(lambda x: pd.to_numeric(x, errors='coerce') if x.dtype == 'ignore' else x)
# Out:
# /var/folders/_s/0t16g1qd2sb1tqhbp674fjy00000gn/T/ipykernel_2717/2749887326.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_clean[col] = pd.to_numeric(df_clean[col], errors='ignore')

# %%
medianas = df_clean.median(numeric_only=True)
print("Medianas dos atributos:")
print(medianas)
# Out:
# Medianas dos atributos:
# sepal_length    5.05
# sepal_width     3.45
# petal_length    1.40
# petal_width     0.20
# dtype: float64

# %% [markdown]
# ### Monte um boxplot para cada variável dos dados da Iris. Quais atributos apresentam outliers?

# %%
data = pd.read_csv('../data/iris.csv', header=0)

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(['sepal_length', 'sepal_width', 'petal_length', 'petal_width']):
    plt.subplot(2, 2, i+1)
    sns.boxplot(x="species", y=col, data=data)
    plt.xlabel('Espécie', fontsize=12)
    plt.ylabel(col.replace('_', ' ').title(), fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Considere a base de dados Advertising.csv. Calcule a correlação entre as variáveis. Quais são as variáveis mais correlacionadas?

# %%
df = pd.read_csv('../data/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Calcula a matriz de correlação
correlacoes = df.corr(numeric_only=True)

print("Matriz de correlação:")
print(correlacoes)

# Encontrando as variáveis mais correlacionadas (excluindo a diagonal)
corr_unstacked = correlacoes.abs().unstack()
corr_unstacked = corr_unstacked[corr_unstacked < 1]  # Remove correlação perfeita
mais_correlacionadas = corr_unstacked.sort_values(ascending=False).drop_duplicates().head(1)
print("\nVariáveis mais correlacionadas:")
print(mais_correlacionadas)
# Out:
# Matriz de correlação:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000
#
# Variáveis mais correlacionadas:
# sales  TV    0.782224
# dtype: float64

# %% [markdown]
# #### Plotando essa correlação

# %%
# Calcula a matriz de correlação
correlacoes = df.corr(numeric_only=True)

# Plota o heatmap da matriz de correlação
plt.figure(figsize=(8,6))
sns.heatmap(correlacoes, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação - Advertising')
plt.show()
